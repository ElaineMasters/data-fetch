# %%
#国联安512480ETF 第一次爬虫尝试失败
#国联安512480ETF 第二次爬虫也失败 只能获取最新一天的申赎，没有日期作为headers的参数
import requests
import csv


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\512480ETF.csv'


csv_header = ['Date', 'Content']


with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)


    for year in range(2024, 2025): 
        for month in range(1, 6):  
            for day in range(1, 32):  
                date_str = f"{year}-{month:02}{day:02}"
                url = f"https://www.cpicfunds.com/fund/EtfFund/eftDownFlie.htm?fundcode=512480&etfdate={date_str}"

                # 发起请求
                response = requests.get(url)
                if response.status_code == 200:
                    text_content = response.text
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#华宝中证医疗512170ETF 爬虫测试
import requests
import csv

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\512170ETF.csv'


csv_header = ['Date', 'Content']

with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    for year in range(2024, 2025):  
        for month in range(1, 6):  
            for day in range(1, 32):  
                date_str = f"{year}-{month:02}-{day:02}"
                url = 'https://www.fsfund.com/hbdynamic/selDayInfo.do'
                para = {'vc_fundcode': '512170',
                        'd_tradingday': date_str}

                response = requests.post(url,headers=headers,data=para)
                if response.status_code == 200:
                    text_content = response.text
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#华宝中证医疗512170ETF 
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime, timedelta

# 设置请求头
headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

# 输出文件路径
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\512170ETF.csv'
data_list = []
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '固定替代金额', '申购溢价比例', '赎回折价比例'])
    start_date = datetime(2024, 6, 11)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y-%m-%d')
            url = 'https://www.fsfund.com/hbdynamic/selDayInfo.do'
            para = {'vc_fundcode': '512170', 'd_tradingday': str(date_str)}

            response = requests.post(url, headers=headers, data=para)
            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.find_all('table', class_='rates-table')
            table = table[2]
            rows = table.find_all('tr')
            for row in rows[1:]:  
                columns = row.find_all('td')
                data = [
                    date_str,
                    columns[0].text.strip(),  # 股票代码
                    columns[1].text.strip(),  # 股票简称
                    columns[2].text.strip(),  # 股票数量
                    columns[3].text.strip(),  # 现金替代标志
                    columns[4].text.strip(),  # 现金替代溢价比例
                    columns[5].text.strip(),  # 赎回折价比例
                    columns[6].text.strip(),  # 固定替代金额
                ]
                data_list.append(data)

        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))
    for row in data_list:
        writer.writerow(row)

# %%
#华宝中证医疗512170ETF 
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime, timedelta

# 设置请求头
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

# 输出文件路径
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\行业\华宝医疗512170ETF.csv'
data_list = []

# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期', '股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '固定替代金额', '申购溢价比例', '赎回折价比例'])

    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date:
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y-%m-%d')
            url = 'https://www.fsfund.com/hbdynamic/selDayInfo.do'
            para = {'vc_fundcode': '512170', 'd_tradingday': str(date_str)}

            response = requests.post(url, headers=headers, data=para)
            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.find_all('table', class_='rates-table')

            # 检查是否找到了表格
            if table:
                table = table[2]
                rows = table.find_all('tr')
                # 检查rows是否为空或者只包含标题行
                if len(rows) > 1:
                    for row in rows[1:]:  # 从第二行开始，跳过标题行
                        columns = row.find_all('td')
                        # 确保列的数量足够
                        if len(columns) >= 7:
                            data = [
                                date_str,
                                columns[0].text.strip(),  # 股票代码
                                columns[1].text.strip(),  # 股票名称
                                columns[2].text.strip(),  # 股票数量
                                columns[3].text.strip(),  # 现金替代标志
                                columns[4].text.strip(),  # 现金替代溢价比例
                                columns[5].text.strip(),  # 申购溢价比例
                                columns[6].text.strip(),  # 赎回折价比例
                            ]
                            data_list.append(data)
                        else:
                            print(f"在 {date_str} 缺少数目不正确的列。")
                else:
                    print(f"在 {date_str} 没有找到数据行。")
            else:
                print(f"在 {date_str} 没有找到表格。")

        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))

    # 写入数据到CSV文件
    for row in data_list:
        writer.writerow(row)
# Out:
# 在 2024-01-01 缺少数目不正确的列。
# 在 2024-02-09 缺少数目不正确的列。
# 在 2024-02-12 缺少数目不正确的列。
# 在 2024-02-13 缺少数目不正确的列。
# 在 2024-02-14 缺少数目不正确的列。
# 在 2024-02-15 缺少数目不正确的列。
# 在 2024-02-16 缺少数目不正确的列。
# 在 2024-04-04 缺少数目不正确的列。
# 在 2024-04-05 缺少数目不正确的列。
# 在 2024-05-01 缺少数目不正确的列。
# 在 2024-05-02 缺少数目不正确的列。
# 在 2024-05-03 缺少数目不正确的列。
# 在 2024-06-10 缺少数目不正确的列。

# %%
#华宝医疗ETF512170现金差额
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime, timedelta

# 设置请求头
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

# 输出文件路径
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\现金差额\华宝医疗ETF512170现金差额.csv'
data_list = []

# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期', '股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '固定替代金额', '申购溢价比例', '赎回折价比例'])

    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date:
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y-%m-%d')
            url = 'https://www.fsfund.com/hbdynamic/selDayInfo.do'
            para = {'vc_fundcode': '512170', 'd_tradingday': str(date_str)}

            response = requests.post(url, headers=headers, data=para)
            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.find_all('table', class_='rates-table')

            # 检查是否找到了表格
            if table:
                table = table[0]
                rows = table.find_all('tr')
                if len(rows) > 1:
                    data= [date_str,rows[1].text.strip()]
                    data_list.append(data)
                
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))

    # 写入数据到CSV文件
    for row in data_list:
        writer.writerow(row)

# %%
#广发中证传媒 512980ETF爬虫测试1
import requests
from bs4 import BeautifulSoup
import json

headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

url = 'https://www.gffunds.com.cn/proxy/pcflist/512980?date=20240101'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
data1 = {
  'date': '20240101'
}
response = requests.post(url,headers=headers,data=data1)

# %%
#广发中证传媒 512980ETF爬虫测试2
date_str='2024-07-01'
url = 'https://www.gffunds.com.cn/proxy/pcflist/512980?date=20240101'

headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'date': '20240101'
}

# 使用requests.post发起POST请求
response = requests.post(url, headers=headers, data=data1)

# 获取响应内容
response_content = response.content

# 尝试将响应内容解析为字符串
try:
    html = response_content.decode('utf-8')  # 使用utf-8编码方式
except UnicodeDecodeError as e:
    print(f"解码错误: {e}")
soup = BeautifulSoup(html, 'html.parser')
tables=soup.find_all('table')
table=tables[1]
from bs4 import BeautifulSoup
import csv

# 假设您已经有一个变量tables，它是soup.find_all('table')的结果
# tables = soup.find_all('table')

# 定位特定的表格
table = tables[1]

checklist_rows = table.find_all('tr', class_='checkList')

# 提取每行的数据，并保存到CSV文件
output_file = 'testt.csv'
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    # 写入标题行
    writer.writerow([f'{date_str}',"证券代码", "证券简称", "证券数量", "现金替代标志", "溢价比例", "折价比例", "固定替代金额"])
    
    # 写入数据行
    for row in checklist_rows:
        columns = row.find_all('td')
        data = [column.text.strip() for column in columns]
        writer.writerow(data[0:7])
        data_list.append(data[0:7])
print(f"CSV output saved to {output_file}")


data_list

# %%
#wc -l 中证传媒 512980ETF
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime, timedelta
data_list = []
headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

# 输出文件路径
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\512980ETF.csv'
data_list = []
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '现金替代溢价比例', '固定替代金额'])
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y%m%d')
            url = f'https://www.gffunds.com.cn/proxy/pcflist/512980?date={date_str}'
            para = {
                'date': date_str
            }
            response = requests.post(url, headers=headers, data=para)
            response_content = response.content
            html = response_content.decode('utf-8')
            soup = BeautifulSoup(html, 'html.parser')
            tables=soup.find_all('table')
            table=tables[1]
            checklist_rows = table.find_all('tr', class_='checkList')
            for row in checklist_rows:
                columns = row.find_all('td')
                data = [column.text.strip() for column in columns]
               
                data_list.append([date_str]+data[0:7])
 
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))
    for row in data_list:
        writer.writerow(row)

# %%
#广发中证传媒 512980ETF 现金差额
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime, timedelta
data_list = []
headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

# 输出文件路径
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\现金差额\广发传媒512980ETF.csv'
data_list = []
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '现金替代溢价比例', '固定替代金额'])
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y%m%d')
            url = f'https://www.gffunds.com.cn/proxy/pcflist/512980?date={date_str}'
            para = {
                'date': date_str
            }
            response = requests.post(url, headers=headers, data=para)
            response_content = response.content
            html = response_content.decode('utf-8')
            soup = BeautifulSoup(html, 'html.parser')
            tables=soup.find_all('table')
            table=tables[1]
            tt = table.find_all('tbody')
            tt = tt[8]
            kk = tt.find_all('tr')
            kk= kk[3]
            td=kk.find_all('td')[1]
            div = td.find('div', {'id': 'CashComponent'})
            data= [ date_str, div ]
            data_list.append(data)
        
 
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))
    for row in data_list:
        writer.writerow(row)

# %%
url = f'https://www.gffunds.com.cn/proxy/pcflist/512980?date={20240701}'
para = {
    'date': '20240701'}
response = requests.post(url, headers=headers, data=para)
response_content = response.content
html = response_content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
tables=soup.find_all('table')
table=tables[1]
checklist_rows = table.find_all('tr', class_='checkList')
checklist_rows
# Out:
# [<tr class="checkList">
#  <td align="middle"><div class="checkCol0" id="Cstockcode0">000156</div>
#  </td>
#  <td align="middle"><div class="checkCol1" id="Cstockshort0">华数传媒</div>
#  </td>
#  <td align="middle"><div class="checkCol2" id="Cnumber0">1800</div>
#  </td>
#  <td align="middle"><div class="checkCol3" id="Ctdbz0">深市退补</div>
#  </td>
#  <td align="middle"><div class="checkCol4" id="Cyjbl0">15.000%</div></td>
#  <td align="middle"><div class="checkCol4">15.000%</div></td>
#  <td align="middle"><div class="checkCol5" id="Ctdje0">11304</div></td>
#  <tr class="checkList">
#  <td align="middle"><div class="checkCol0" id="Cstockcode1">000681</div>
#  </td>
#  <td align="middle"><div class="checkCol1" id="Cstockshort1">视觉中国</div>
#  </td>
#  <td align="middle"><div class="checkCol2" id="Cnumber1">900</div>
#  </td>
#  <td align="middle"><div class="checkCol3" id="Ctdbz1">深市退补</div>
#  </td>
#  <td align="middle"><div class="checkCol4" id="Cyjbl1">15.000%</div></td>
# ...

# %%
#富国中证农业主题ETF 159825  爬虫加密
58db26f260eyJmdW5kQ29kZSI6IjE1OTgyNSIsImZpbGVEYXRlIjoiMjAyNDA3MjIiLCJ0IjoiMjAyNC0wNy0yMlQwOTowMjowOC4xMDhaIn0=11881

# %%
#嘉实中证500 159922 爬虫test
import requests
from bs4 import BeautifulSoup
import csv
url = f"http://download.jsfund.cn/pcf/159922_1/2024/pcf_159922_20240701.xml"
response = requests.get(url)
if response.status_code == 200:
    html = response.text
soup = BeautifulSoup(html, 'html.parser')
print(html)

# %%
#嘉实中证500 159922 爬虫第一次尝试FAIL

import requests
import csv


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159922ETF.csv'

# 准备CSV文件的表头
csv_header = ['Date', 'Content']

# 打开CSV文件准备写入数据
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    # 迭代请求不同日期的数据
    for year in range(2024, 2025):  # 年份范围，从2024年到2024年
        for month in range(1, 7):  # 月份范围，从1月到12月
            for day in range(1, 32):  # 日范围，从1号到31号（实际上不会超过当月的天数）
                # 构建日期字符串
                date_str = f"{year}{month:02}{day:02}"
                # 构建完整的URL
                url = f"http://download.jsfund.cn/pcf/159922_1/2024/pcf_159922_{date_str}.xml"

                # 发起请求
                response = requests.get(url)
                if response.status_code == 200:
                    # 获取文本内容
                    text_content = response.text
                    # 将日期和内容写入CSV文件
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#嘉实中证500 159922第二次
import requests
from bs4 import BeautifulSoup
import csv
import json
from datetime import datetime, timedelta
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159922ETF.csv'
# 目标网页URL
url = 'https://www.jsfund.cn/servlet/json'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'funcNo': '741031',
    'product_code': '159922_1',
    'query_date': '2024-07-01'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text
html
data=json.loads(html)
type(data['stock_info'])
data_list=[]
for item in data['stock_info']:
    data_list.append(item)
data_list

# %%
#嘉实中证500ETF 159922爬虫第三次尝试 成功
import requests
from bs4 import BeautifulSoup
import csv
import json
from datetime import datetime, timedelta
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159922ETF.csv'
# 目标网页URL
url = 'https://www.jsfund.cn/servlet/json'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
data_list = []
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '现金替代溢价比例', '固定替代金额'])
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y-%m-%d')
            para = {
                'funcNo': '741031',
                'product_code': '159922_1',
                'query_date': date_str
              }
            response = requests.post(url, headers=headers, data=para)
            html = response.text
            data=json.loads(html)
            temp = []
            for item in data['stock_info']:
                temp.append(item)
            updated_data = [{k: v if k != 'csubstcashamt' else date_str for k, v in item.items()} for item in temp]
            data_list.append(updated_data)
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))  
        
    columns = list(data_list[1][0].keys())

# 写入CSV文件
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(columns)  # 写入标题行
    for i in range(len(data_list)):
        for item in data_list[i]:
            row = []
            for column in columns:
                row.append(item[column])
            writer.writerow(row)  # 写入数据行

print(f"CSV output saved to {output_file}")

# %%
#wc -l 中证计算机ETF 512720 
import requests
import csv


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\512720ETF.csv'

# 准备CSV文件的表头
csv_header = ['Date', 'Content']

# 打开CSV文件准备写入数据
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    # 迭代请求不同日期的数据
    for year in range(2024, 2025):  # 年份范围，从2024年到2024年
        for month in range(1, 7):  # 月份范围，从1月到12月
            for day in range(1, 32):  # 日范围，从1号到31号（实际上不会超过当月的天数）
                # 构建日期字符串
                date_str = f"{year}-{month:02}-{day:02}"
                # 构建完整的URL
                url = f"https://e.gtfund.com/Etrade/FundDetail/getETFFile/id/512721/date/{date_str}"

                # 发起请求
                response = requests.get(url)
                if response.status_code == 200:
                    # 获取文本内容
                    text_content = response.text
                    # 将日期和内容写入CSV文件
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#永赢中证全指医疗器械ETF 159883 第一次爬虫尝试 失败

import requests
import csv


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159883ETF.csv'

# 准备CSV文件的表头
csv_header = ['Date', 'Content']

# 打开CSV文件准备写入数据
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    # 迭代请求不同日期的数据
    for year in range(2024, 2025):  # 年份范围，从2024年到2024年
        for month in range(1, 7):  # 月份范围，从1月到12月
            for day in range(1, 32):  # 日范围，从1号到31号（实际上不会超过当月的天数）
                # 构建日期字符串
                date_str = f"{year}{month:02}{day:02}"
                # 构建完整的URL
                url = f"https://owa.maxwealthfund.com/gateway/aresoft-product/etfFile/etfInfo?prdCode=159883&date={date_str}"

                # 发起请求
                response = requests.get(url)
                if response.status_code == 200:
                    # 获取文本内容
                    text_content = response.text
                    # 将日期和内容写入CSV文件
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#永赢中证全指医疗器械ETF 159883 第二次爬虫尝试
# 导入模块
import requests
import csv
import json
url = 'https://owa.maxwealthfund.com/gateway/aresoft-product/etfFile/etfInfo?prdCode=159883&date=20240701'
# 定义自定义请求头
headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
# 定义 GET 请求参数
params = {
    'prdCode': '159883',
    'date': '20240701'
}
response = requests.get(url,headers=headers,params=params)
html = response.text
df =json.loads(html)
temp=[]
for item in df['dta']

# %%
#永赢中证全指医疗器械ETF 159883 第三次爬虫尝试
from bs4 import BeautifulSoup
import csv
import json
from datetime import datetime, timedelta
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159883ETF.csv'


headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
data_list = []
temp=[]
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '现金替代溢价比例', '固定替代金额'])
    start_date = datetime(2024, 7, 21)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y%m%d')
            url = f'https://owa.maxwealthfund.com/gateway/aresoft-product/etfFile/etfInfo?prdCode=159883&date={date_str}'
            para = {
                'prdCode': '159883',
                'date': date_str
              }
            response = requests.post(url, headers=headers, data=para)
            html = response.text
            print(html)
           
            
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))  
        
print(html)

# %%
#永赢中证全指医疗器械ETF 159883 循环失败
import time
for year in range(2024, 2025):  # 年份范围，从2024年到2024年
        for month in range(1, 7):  # 月份范围，从1月到12月
            for day in range(1, 32):  # 日范围，从1号到31号（实际上不会超过当月的天数）
                # 构建日期字符串
                date_str = f"{year}{month:02}{day:02}"
                url = f'https://owa.maxwealthfund.com/gateway/aresoft-product/etfFile/etfInfo?prdCode=159883&date={date_str}'
                para = {
                    'prdCode': '159883',
                    'date': date_str
                }
                response = requests.post(url, headers=headers, data=para)
                html = response.text
                print(html)
            time.sleep(10)

# %%
#鹏华沪深300ETF 159673 trial 1
import requests
from bs4 import BeautifulSoup
import pandas as pd

output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159673ETF.csv'

url = 'https://www.phfund.com.cn/web/funddetail_etf?fundcode=159673&queryDate=2024-07-04'


headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'fundcode': '159673',
    'queryDate': '2024-07-04'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text

# %%
#平安创业板ETF 159964 trial 1 
import requests
import csv

output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159964ETF.csv'
csv_header = ['Date', 'Content']
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    for year in range(2024, 2025):  
        for month in range(1, 7): 
            for day in range(1, 32): 
                date_str = f"{year}{month:02}{day:02}"
                date_str1 = f"{year}-{month:02}-{day:02}"
                url = f"https://fund.pingan.com/servlet/EtfdownloadAction?tdate={date_str1}&code=159964&filename=pcf_159964_{date_str}.xml"

                response = requests.get(url)
                if response.status_code == 200:
                    text_content = response.text
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#平安创业板ETF 159964 trial 2
import requests
from lxml import etree
import csv
url = f"https://fund.pingan.com/servlet/EtfdownloadAction?tdate=2024-07-22&code=159964&filename=pcf_159964_20240722.xml"
response = requests.get(url)
html_bytes = response.text
html_e = etree.XML(html_bytes)

# %%
html_bytes

# %%
#银华中证虚拟现实主题ETF 159786 trial 1 FAIL
import requests
import csv


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159786ETF.csv'
csv_header = ['Date', 'Content']
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    for year in range(2024, 2025):  
        for month in range(1, 7): 
            for day in range(1, 32): 
                date_str = f"{year}{month:02}{day:02}"
                url = f"https://www.yhfund.com.cn/etffiles/2024/pcf_159786_{date_str}.xml"

                response = requests.get(url)
                if response.status_code == 200:
                    text_content = response.text
                    writer.writerow([date_str, text_content])
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")

# %%
#银华中证虚拟现实主题ETF 159786 test FAIL
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 目标网页URL
url = 'https://www.yhfund.com.cn/servlet/json'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'product_code': '159786',
    'select_time': '2024-07-23',
    'isfield': '1',
    'funcNo': '742018'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text
html

# %%
#创新药ETF沪港深 159622 trial 1
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# 目标网页URL
url = 'https://www.dongcaijijin.com/etf/queryPRInfo'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'fundCode': '159622',
    'date': '20240604'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text
data = json.loads(html)
data_list=[]
for item in data['list']:
    data_list.append(item)
print(data_list[0][0])

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# 目标网页URL
url = 'https://www.dongcaijijin.com/etf/queryPRInfo'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

data1 = {
    'fundCode': '159622',
    'date': '20240604'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text
data = json.loads(html)
data
# Out:
# {'list': [{'underlyingSymbol': '申赎现金',
#    'creationCashSubstitute': '570,144.3900',
#    'premiumRatio': '',
#    'substituteFlag': '必须',
#    'underlyingSecurityID': '159900',
#    'componentShare': '',
#    'redemptionCashSubstitute': '212,719.6500',
#    'underlyingSecurityIDSource': '深圳市场',
#    'discountRatio': ''},
#   {'underlyingSymbol': '丽珠集团',
#    'creationCashSubstitute': '',
#    'premiumRatio': '10%',
#    'substituteFlag': '允许',
#    'underlyingSecurityID': '000513',
#    'componentShare': '200',
#    'redemptionCashSubstitute': '',
#    'underlyingSecurityIDSource': '深圳市场',
#    'discountRatio': ''},
#   {'underlyingSymbol': '长春高新',
#    'creationCashSubstitute': '',
#    'premiumRatio': '10%',
#    'substituteFlag': '允许',
#    'underlyingSecurityID': '000661',
#    'componentShare': '200',
#    'redemptionCashSubstitute': '',
#    'underlyingSecurityIDSource': '深圳市场',
#    'discountRatio': ''},
#   {'underlyingSymbol': '华东医药',
#    'creationCashSubstitute': '',
# ...

# %%
#创新药ETF沪港深 159622 trial 2
from bs4 import BeautifulSoup
import csv
import json
from datetime import datetime, timedelta
output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\159622ETF.csv'


headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}
data_list = []
# 创建CSV文件和写入器
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 写入CSV标题行
    writer.writerow(['日期','股票代码', '股票名称', '股票数量', '现金替代标志', '现金替代溢价比例', '现金替代溢价比例', '固定替代金额'])
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 7, 22)

    current_date = start_date
    while current_date <= end_date: 
        if current_date.weekday() < 5:  # weekday() 返回星期的索引，星期一为0，星期天为6
            date_str = current_date.strftime('%Y%m%d')
            url = 'https://www.dongcaijijin.com/etf/queryPRInfo'
            para = {
                'fundCode': '159622',
                'date': date_str
              }
            response = requests.post(url, headers=headers, data=para)
            html = response.text
            data = json.loads(html)
            temp=[]
            for item in data['list']:
                temp.append(item)
            updated_data = [{k: v if k != 'discountRatio' else date_str for k, v in item.items()} for item in temp]
            data_list.append(updated_data) 
            
        current_date += timedelta(days=(1 if current_date.weekday() < 5 else 2))  
        
       

# 写入CSV文件
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
      # 写入标题行
    for i in range(len(data_list)):
        for item in data_list[i]:
            row = []
            for column in columns:
                row.append(item[column])
            writer.writerow(row)  # 写入数据行

print(f"CSV output saved to {output_file}")

# %%
#招商中证物联网主题ETF 159701 test
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 目标网页URL
url = 'https://www.cmfchina.com/servlet/fund/ETFSearchAction?fundId=159701&startTime=2024-05-28&reqUrl=%2Fservlet%2Ffund%2FETFSearchAction&_=1721718178530'

headers = {
  "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"
}

https://www.cmfchina.com/servlet/fund/ETFSearchAction?fundId=159701&startTime=2024-05-16&reqUrl=%2Fservlet%2Ffund%2FETFSearchAction&_=1721718306690
data1 = {
  'beginDate': '2024-07-19',
  'fundcode' : '510300'
}
response = requests.post(url,headers=headers,data=data1)

html = response.text

# %%
#易方达中证人工智能 159819 循环输出trial 1
import requests
import csv
import xml.etree.ElementTree as ET


output_file = r'C:\Users\jinwe\Desktop\quant\ETF\data\行业\易方达人工智能159819ETF.csv'
csv_header = ['UnderlyingSecurityID', 'UnderlyingSecurityIDSource', 'UnderlyingSymbol', 'ComponentShare', 'SubstituteFlag', 'PremiumRatio', 'CreationCashSubstitute', 'RedemptionCashSubstitute']
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(csv_header)

    for year in range(2024, 2025):  
        for month in range(1, 7): 
            for day in range(1, 32): 
                date_str = f"{year}{month:02}{day:02}"
                url = f'https://cdn.efunds.com.cn/owch/data/pcf_ims/{date_str}/pcf_159819_{date_str}.xml'
                response = requests.get(url)
                if response.status_code == 200:
                    text_content = response.text
                    root = ET.fromstring(text_content)
                    namespace = {'ns': 'http://ts.szse.cn/Fund'}
                    components = root.find('ns:Components', namespace)
                    for component in components.findall('ns:Component', namespace):
                        csv_row = []
                        for header in csv_header:
                            element = component.find(f'ns:{header}', namespace)
                            csv_row.append(element.text if element is not None else '')
                        writer.writerow(date_str)
                        writer.writerow(csv_row)
                        
                    print(f"Successfully fetched data for {date_str}")
                else:
                    print(f"Failed to fetch data for {date_str}")

print(f"CSV output saved to {output_file}")
# Out:
# Failed to fetch data for 20240101
# Successfully fetched data for 20240102
# Successfully fetched data for 20240103
# Successfully fetched data for 20240104
# Successfully fetched data for 20240105
# Failed to fetch data for 20240106
# Failed to fetch data for 20240107
# Successfully fetched data for 20240108
# Successfully fetched data for 20240109
# Successfully fetched data for 20240110
# Successfully fetched data for 20240111
# Successfully fetched data for 20240112
# Failed to fetch data for 20240113
# Failed to fetch data for 20240114
# Successfully fetched data for 20240115
# Successfully fetched data for 20240116
# Successfully fetched data for 20240117
# Successfully fetched data for 20240118
# Successfully fetched data for 20240119
# Failed to fetch data for 20240120
# Failed to fetch data for 20240121
# Successfully fetched data for 20240122
# Successfully fetched data for 20240123
# Successfully fetched data for 20240124
# Successfully fetched data for 20240125
# ...
